# %% [markdown]
# # 漸く森博嗣「笑わない数学者」のビリヤードの問題／魔円陣を解いたものの要領を良くする
# 素数 $p$ に対して,  $A,B,C$ を $0,\ 1,\ \cdots,\ p-1$ で逐次試して,
# + $C\ne 0$ や $A=B=0$ でない
# + $x=1,...,p-1$ を代入し $x^3+Ax^2+Bx+C$ が $0$ にならない事(既約多項式であること)を確認
# + $(a_0,b_0,c_0)=(0,0,1)$ から始めて, $(a_i,b_i,c_i)$ を漸化式から順に計算し, $i=p^2+p+1$ のとき始めて $a_i=b_i=0$ になることを確認する
#
# という要領。
# 先ずは, 環境の確認と, **Pkg**の導入から

# %%
println(versioninfo())
using Nemo,Combinatorics,Dates,Primes
# Out:
# Julia Version 1.10.4
# Commit 48d4fd48430 (2024-06-04 10:41 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: macOS (arm64-apple-darwin22.4.0)
#   CPU: 8 × Apple M3
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-15.0.7 (ORCJIT, apple-m1)
# Threads: 1 default, 0 interactive, 1 GC (on 4 virtual cores)
# nothing

# %% [markdown]
# 最初の2つの条件を満たす **[A,B,C]** のリストを拵える...と$p$が大きくなったときに効率が悪いので...
# ランダムに **[A,B,C]** を取り上げて... チェックしてから試してみる。

# %%
start = Dates.now()
p=1009
chk=false
while chk!=true
    A,B,C=rand(0:p-1),rand(0:p-1),rand(0:p-1)
    if C!=0 && !(A==0 && B==0)
        chkA=true
        for x=1:p-1
            if (x^3+A*x^2+B*x+C)%p==0
                chkA=false
                break
            end
        end
    end
    if chkA
        ABC=[A,B,C]
        abc=[0,0,1]
        abclst=[abc]
        for i=1:p^2+p+1
            nxtabc=[(-ABC[1]*abc[1]+abc[2]+p^2)%p,(-ABC[2]*abc[1]+abc[3]+p^2)%p,(-ABC[3]*abc[1]+p^2)%p]
            push!(abclst,nxtabc)
            if nxtabc[1]==0 && nxtabc[2]==0
                break
            else
                abc=nxtabc
            end
        end
        if length(abclst)>p^2+p+1
            chk=true
            prnstr=[]
            for e ∈ abclst[1:5]
                push!(prnstr,"("*join(e,",")*")")
            end
            push!(prnstr," ... ")
            for e ∈ abclst[end-4:end]
                push!(prnstr,"("*join(e,",")*")")
            end
            cds=[]
            for i=1:length(abclst)
                if abclst[i][1]==0
                    push!(cds,i-1)
                end
            end
            bbl=[]
            for i=1:length(cds)-1
                push!(bbl,cds[i+1]-cds[i])
            end
            println(join(prnstr,",")," : ",length(abclst),", ",p^2+p+1)
            println("=> ("*join(cds,",")*")")
            println("-> ("*join(bbl,",")*")")
            break
        end
    end
end
dtime = Dates.now() - start
println("かかった時間: ",dtime.value/1000,"秒だから",dtime.value/60000,"分")
# Out:
# (0,0,1),(0,1,0),(1,0,0),(195,445,288),(128,289,665), ... ,(449,324,472),(96,495,160),(44,502,405),(1,814,564),(0,0,288) : 1019092, 1019091
# => (0,1,574,830,1181,1796,1975,2435,4725,4907,4951,6199,8438,9037,9107,9576,9764,11031,11912,11965,12085,12274,15020,16069,17006,19350,19696,20152,21303,23592,24623,24770,25233,25355,25775,26117,26638,27723,28816,29314,30697,31967,35235,39826,40143,40761,42269,42696,43135,44953,45319,48451,48860,49748,52436,53217,53718,55819,56757,56975,57885,58686,59329,59787,60644,61340,62058,63094,63372,64393,65710,67182,67189,71047,76528,77023,78128,78607,79991,80284,81047,82629,85717,86193,86910,87604,87912,88017,88373,89374,89520,89535,89568,89899,90313,90723,90961,91139,91404,91892,92192,93264,93881,95688,97282,97405,101005,102053,102122,103626,103717,103744,104673,104692,105117,106143,108307,108348,110278,112941,114617,114649,114760,117517,118487,119974,121034,121895,122284,122426,122872,124280,124576,125171,126168,126774,127331,128156,129379,130128,132869,133830,133995,134133,134859,134936,137762,138255,140153,140891,141451,142067,146390,146619,146913,148055,148322,149828,152674,155654,155716,156784,159015,159587,159641,160751,162041,164216,166363,167626,168041,169966,171312,176591,178219,178432,179120,179284,179585,180162,180252,180793,184349,185717,187701,189756,189817,190660,191406,191499,192879,194173,194992,195704,196383,196458,197216,197958,200694,201027,201384,201508,201767,202519,203863,204325,204795,207482,207930,208181,210464,215412,216793,216869,216978,218307,218885,219112,222457,222831,223467,223977,224624,228407,228825,231273,232178,232441,235050,235500,239266,239275,239895,240026,240815,243939,244494,244899,245934,246111,246278,246709,248348,249201,249354,250068,250115,251443,251543,251767,252524,252537,254580,255366,255658,255839,255990,256926,256997,257078,258481,259357,259728,261363,261586,262841,263371,263376,264379,264466,265066,266081,266899,267253,267540,267916,268180,269499,270047,270396,270608,271170,272032,272359,273387,274428,274487,274536,274603,275413,275654,276258,276300,277380,278721,278919,281422,281704,283496,288240,290342,291079,291249,292158,292364,292902,295447,295548,297181,299233,301987,303988,304302,304808,307279,309561,310372,310767,311427,313134,313345,313636,313650,315765,317712,317742,318276,318412,319495,319692,320074,320327,321556,321636,322586,324188,326420,332232,333599,333639,338289,339632,340865,341117,341663,341885,342110,344043,345489,346363,346852,347335,347359,348012,350585,350591,350683,352229,352260,353399,355200,357052,358549,358632,359161,359805,360488,361809,362852,366569,367102,367909,368337,371547,371954,372775,372903,374268,376465,377367,381103,381968,383268,383950,386254,386394,386580,387842,388408,389355,389592,389842,389930,391078,391401,391466,392232,394008,394772,397085,397184,397870,399571,401715,402214,402575,403790,404258,404344,406002,406159,406237,406263,408361,408400,408745,408763,413139,413771,415660,418254,418780,419528,420480,420965,421439,421851,426275,426371,427546,427620,427628,427794,430212,432069,433212,433821,434618,435012,435670,436148,436767,437566,439182,439873,441516,442043,442677,442892,443420,443817,443874,444079,444129,445589,447689,448420,449658,451849,453578,454682,455284,458886,460340,460759,461136,461565,462301,462473,464747,464820,465099,466837,469517,469736,470011,470251,470616,471322,472217,473175,476255,476838,477140,477246,477732,478030,480531,480967,484003,484659,485551,486120,486804,487508,487867,488331,489201,491518,492216,492241,494294,494711,494965,495546,495861,495988,496301,496591,496877,497002,498187,499614,500013,500646,500975,502033,507366,508017,508890,510712,511221,514590,516088,516568,518138,518587,519053,520727,521681,522681,523632,524630,524702,525835,526276,527303,527580,527740,528367,528462,530697,531514,533210,533981,535257,536185,536230,537563,541936,544117,544288,544825,545789,546672,547285,547516,547551,547709,550115,550307,550515,552507,552737,553204,553532,554462,556218,556418,557230,561093,563066,563370,564481,567198,567301,568808,569394,571632,574071,575634,576481,578378,579276,581316,581464,583473,584815,585364,5856 ...
# -> (1,573,256,351,615,179,460,2290,182,44,1248,2239,599,70,469,188,1267,881,53,120,189,2746,1049,937,2344,346,456,1151,2289,1031,147,463,122,420,342,521,1085,1093,498,1383,1270,3268,4591,317,618,1508,427,439,1818,366,3132,409,888,2688,781,501,2101,938,218,910,801,643,458,857,696,718,1036,278,1021,1317,1472,7,3858,5481,495,1105,479,1384,293,763,1582,3088,476,717,694,308,105,356,1001,146,15,33,331,414,410,238,178,265,488,300,1072,617,1807,1594,123,3600,1048,69,1504,91,27,929,19,425,1026,2164,41,1930,2663,1676,32,111,2757,970,1487,1060,861,389,142,446,1408,296,595,997,606,557,825,1223,749,2741,961,165,138,726,77,2826,493,1898,738,560,616,4323,229,294,1142,267,1506,2846,2980,62,1068,2231,572,54,1110,1290,2175,2147,1263,415,1925,1346,5279,1628,213,688,164,301,577,90,541,3556,1368,1984,2055,61,843,746,93,1380,1294,819,712,679,75,758,742,2736,333,357,124,259,752,1344,462,470,2687,448,251,2283,4948,1381,76,109,1329,578,227,3345,374,636,510,647,3783,418,2448,905,263,2609,450,3766,9,620,131,789,3124,555,405,1035,177,167,431,1639,853,153,714,47,1328,100,224,757,13,2043,786,292,181,151,936,71,81,1403,876,371,1635,223,1255,530,5,1003,87,600,1015,818,354,287,376,264,1319,548,349,212,562,862,327,1028,1041,59,49,67,810,241,604,42,1080,1341,198,2503,282,1792,4744,2102,737,170,909,206,538,2545,101,1633,2052,2754,2001,314,506,2471,2282,811,395,660,1707,211,291,14,2115,1947,30,534,136,1083,197,382,253,1229,80,950,1602,2232,5812,1367,40,4650,1343,1233,252,546,222,225,1933,1446,874,489,483,24,653,2573,6,92,1546,31,1139,1801,1852,1497,83,529,644,683,1321,1043,3717,533,807,428,3210,407,821,128,1365,2197,902,3736,865,1300,682,2304,140,186,1262,566,947,237,250,88,1148,323,65,766,1776,764,2313,99,686,1701,2144,499,361,1215,468,86,1658,157,78,26,2098,39,345,18,4376,632,1889,2594,526,748,952,485,474,412,4424,96,1175,74,8,166,2418,1857,1143,609,797,394,658,478,619,799,1616,691,1643,527,634,215,528,397,57,205,50,1460,2100,731,1238,2191,1729,1104,602,3602,1454,419,377,429,736,172,2274,73,279,1738,2680,219,275,240,365,706,895,958,3080,583,302,106,486,298,2501,436,3036,656,892,569,684,704,359,464,870,2317,698,25,2053,417,254,581,315,127,313,290,286,125,1185,1427,399,633,329,1058,5333,651,873,1822,509,3369,1498,480,1570,449,466,1674,954,1000,951,998,72,1133,441,1027,277,160,627,95,2235,817,1696,771,1276,928,45,1333,4373,2181,171,537,964,883,613,231,35,158,2406,192,208,1992,230,467,328,930,1756,200,812,3863,1973,304,1111,2717,103,1507,586,2238,2439,1563,847,1897,898,2040,148,2009,1342,549,288,367,217,957,1599,689,571,1458,875,386,4,1057,438,236,372,1059,360,115,2308,662,11,1991,2208,759,285,52,216,12,2682,547,1733,209,433,4502,145,519,21,1092,451,520,318,2278,2876,2095,97,283,1286,772,336,512,191,1134,2082,1067,246,1352,1013,196,767,435,4568,321,713,1119,102,917,1899,385,1614,652,63,587,163,1369,1687,445,455,661,281,1435,828,370,1781,582,274,2441,492,247,350,343,2370,899,645,195,2917,426,924,320,2245,1713,232,169,150,471,822,725,559,245,591,1450,180,544,1692,1779,570,1758,134,496,783,524,1275,638,144,1597,1812,306,207,989,341,28,1199,430,893,511,112,1242,4011,1125,2054,375,398,514,162,406,780,580,1685,545,945,38,741,36,944,2531,702,3598,79,276,23,477,1417,155,1430,2161,491,17,2890,2720,482,190,20,1875,593,1467,16,295,871,204,552,2852,154,923,859,1018,1086,711,242,3279,1207,969,1112,850,1364,1009,202,334,89,94,1120,434,854,809,1960,654,1433,316,918,2155,2258,1647,858,2376,868,119,1878,1581,221,201,258,1850,1084,1038,943,270,3470,695,2634,113,43,64,233,51,330,4080,184,563,995,199,851,2483,2213,1295,37,955,484,117,1308,1535,310,1732,3483,187,916,68,906,705,2,594,1374,55,978,1718,1488,965,1269,518,999,1394,121,1217,1322,505,622,4035,137,842,2171,913,2034,1481,3259,649,84,1305,1201,1680,1761,1442,4715,135,841,1183,503,2683,1642,1705,260,816,457,2445,3152,141,3491,149,1296,1659,29,392,2738,3589,203,2281,2139,396,404,1390,271,4567,827,159,234,10,129,1177,946,611,967,432,126,2879,339,289,2094,1069,353,637,1266,522,347,1351,919,765,239,2127,2685,921,1241,4892,358,114,113 ...
# かかった時間: 0.628秒だから0.010466666666666668分
